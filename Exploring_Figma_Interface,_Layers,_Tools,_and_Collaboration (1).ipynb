# %% [markdown]
# 1.Dowload and install figma that exports interface projects and team spaces
# -   figma is a collaborative interface design tool available as both a web application and a desktop app for windows and macos. the desktop app provides a more native experience and allows access to locally installed fonts.
#  - canvas - menus and tools like move, frame,shapes,text.
#  - layers panel - managing pages,layers,components
#  - properties panel - adjusting design, prototype, inspect settings
#  ![657bdc2103cc6ceab4842e4e_F101_D1_02.jpeg](data:image/jpeg;base64,...)
#  - project where we have own team library or we can view members and upgrade to create more projects and share this to other team members.
#
# ![Click-on-All-projects.png](data:image/png;base64,...)
# - team spaces are central, collaborative hubs for organizing projects,files, and design systems.here we can create team community, and they have settings.
# ![teamspace_create a team.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# 2.create a new figma file and organize layers properly.
# - use groups,frames, and alignment tools to structure elements neatly
# - practice positioning, resizing, and scale elements effectively
# - GROUPS, FRAMES AND ALIGNMENT TOOLS :
#
#  ![Group 5.png](data:image/png;base64,...)
# - POSITIONING,RESIZING, AND SCALE ELEMENTS :
#
# ![Group 6 (1).png](data:image/png;base64,...)

# %% [markdown]
# 3. experiment with basic tools by creating simple shapes
# - use the rectangle ellipse polygon line and arrow tools to design a basic layout
# - explore the text tool applying different fonts and formatting
#
#
# ![Group 4.png](data:image/png;base64,...)

# %% [markdown]
# 4. use collaboration features to interact with a peer
# - add comments on elements to share feedback
# - share the figma file with the classmate and explore real time editing
# - publisher simple design to the figma community
#
# https://www.figma.com/design/szO4ipUWy3O0orDCk7z1xm?node-id=12-71#1571081813
#
# ![figmasharefile.jpg](data:image/jpeg;base64,...)
#
# https://www.figma.com/community/file/1587008099882216999

# %% [markdown]
# 5. Submit a documented reflection on the learning experience, including:
#
# - Screenshots of the Figma interface and completed tasks
#
# - Key takeaways from exploring Figma’s tools and collaboration features
# -
# ![Menu__Paid____image_10.jpg](data:image/jpeg;base64,...)
#
# - ![Advanced-Collaboration-Features-in-Figma1-copy.webp](data:image/webp;base64,...)
#
# -
# ![3-15-1024x576.png](data:image/png;base64,...)
